# %%
myfile = open("file.txt")

# %%
myfile.readlines()
# Out:
# ['THIS IS A TEXT FILE 1\n',
#  'THIS IS A TEXT FILE 2\n',
#  'THIS IS A TEXT FILE 3 ']

# %%
myfile.readlines()
# Out:
# []

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines()
# Out:
# ['THIS IS A TEXT FILE 1\n',
#  'THIS IS A TEXT FILE 2\n',
#  'THIS IS A TEXT FILE 3 ']

# %%
contents = myfile.readlines()

# %%
contents
# Out:
# []

# %%
myfile.seek(0)
# Out:
# 0

# %%
contents = myfile.readlines()

# %%
contents
# Out:
# ['THIS IS A TEXT FILE 1\n',
#  'THIS IS A TEXT FILE 2\n',
#  'THIS IS A TEXT FILE 3 ']

# %%
myfile.close()

# %%
with open(file.txt) as file_variable:
    contents = myfile.readlines()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 with open(file.txt) as file_variable:
#       2     contents = myfile.readlines()
#
# NameError: name 'file' is not defined

# %%
with open("file.txt") as file_variable:
    contents = file_variable.readlines()

# %%
contents
# Out:
# ['THIS IS A TEXT FILE 1\n',
#  'THIS IS A TEXT FILE 2\n',
#  'THIS IS A TEXT FILE 3 ']

# %%
# %%writefile newfile.txt
# HELLO MY NAME IS KENSEY
# HELLOW MY NAME IS KENSEY
# I AM A DEVOPS ENGINEER
# Out:
# Writing newfile.txt

# %%
with open("newfile.txt",mode='a') as variable: 
    variable.write("Alright sharrrrap your mouth/n")

# %%
with open("newfile.txt",mode='r') as variable:
    variable.read()

# %%
myfile = open("newfile.txt")

# %%
myfile.read()
# Out:
# 'HELLO MY NAME IS KENSEY \nHELLOW MY NAME IS KENSEY\nI AM A DEVOPS ENGINEER \nAlright sharrrrap your mouth/n'

# %%
with open("newfile.txt",mode='r') as variable:
    variable.read()

# %%
with open("newfile.txt",mode='r') as variable:
    print(variable.read())
# Out:
# HELLO MY NAME IS KENSEY
# HELLOW MY NAME IS KENSEY
# I AM A DEVOPS ENGINEER
# Alright sharrrrap your mouth/n

# %%
with open("CREATION.txt",mode='w') as w:
    w.write("I MADE THIS BAD BOY")

# %%
with open("CREATION.txt",mode='r') as r:
     print(r.read())
# Out:
# I MADE THIS BAD BOY

# %%
500 - 399.75
# Out:
# 100.25

# %%
((10000 / 10) * .5) ^ 1 - 399.75
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 ((10000 / 10) * .5) ^ 1 - 399.75
#
# TypeError: unsupported operand type(s) for ^: 'float' and 'float'

# %%
((10000 / 10) * .5) ^ 1 - 399.75
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 ((10000 / 10) * .5) ^ 1 - 399.75
#
# TypeError: unsupported operand type(s) for ^: 'float' and 'float'

# %%
(((10000 / 10) * .5) ^ 1) - 399.75
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 (((10000 / 10) * .5) ^ 1) - 399.75
#
# TypeError: unsupported operand type(s) for ^: 'float' and 'int'

# %%
((10000 / 10) * .5) ** 1 - 399.75
# Out:
# 100.25

# %%
1 + 1
# Out:
# 2

# %%
x = 0 

while x < 5: 
    print(f'The value of x is {x}')
    x = x + 1
# Out:
# The value of x is 0
# The value of x is 1
# The value of x is 2
# The value of x is 3
# The value of x is 4

# %%
for x in range(0,11,2):
    print(x)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
temp = range(0,11)

for x in temp: 
   if x = x % 2
     print(x) 
else print("IDK")
# Out:
#   Cell In[12], line 4
#     if x = x % 2
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
temp = range(0,11)

for x in temp: 
   if x = x % 2
     print(x) 
else print("IDK")
# Out:
#   Cell In[14], line 4
#     if x = x % 2
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
list = []
for word in st.split():
    if word[0] == true: 
    list.append(word[0])
# Out:
#   Cell In[16], line 3
#     if word[0] == true
#                        ^
# SyntaxError: expected ':'

# %%
list = []
for word in st.split():
    if word[0] == true: 
    list.append(word[0])
# Out:
#   Cell In[18], line 4
#     list.append(word[0])
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
help(mylist.insert)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 help(mylist.insert)
#
# NameError: name 'mylist' is not defined

# %%
mylist = [1,2,3]

help(mylist.insert)
# Out:
# Help on built-in function insert:
#
# insert(index, object, /) method of builtins.list instance
#     Insert object before index.

# %%
def say_hello(user):
    input("What is your name," {user})

say_hello(user)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 4
#       1 def say_hello(user):
#       2     input("What is your name, {user}")
# ----> 4 say_hello(user)
#
# NameError: name 'user' is not defined

# %%
def say_hello(user):
    input("What is your name," {user})

say_hello(user)
# Out:
#   Cell In[30], line 2
#     input("What is your name," {user})
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
def say_hello(user):
    print("What is your name? Isn't your name ", user)
    return

user = input("Enter your name -")
result = say_hello(user)
# Out:
# Enter your name - Kensey
# What is your name? Isn't your name  Kensey

# %%
def sum_of_num(x,y):
    print(x+y)
    return

x = input("Insert your first number -")
y = input("Inserr your second number =")

sum_of_num(x,y)
# Out:
# Insert your first number - 100
# Inserr your second number = 100
# 100100

# %%
def sum_of_num(x,y):
    print(int(x)+int(y))
    return

x = input("Insert your first number -")
y = input("Inserr your second number =")

sum_of_num(x,y)
# Out:
# Insert your first number - 100
# Inserr your second number = 100
# 200

# %%
with open("file.txt", 'r') as f:
    print(f.read())
# Out:
# THIS IS A TEXT FILE 1
# THIS IS A TEXT FILE 2
# THIS IS A TEXT FILE 3

# %%
def read_s3(value):
    with open("file.txt", 'a') as f:
    f.write(value)
    return f

read_s3("Adding this to file \n")
# Out:
#   Cell In[44], line 3
#     f.write(value)
#     ^
# IndentationError: expected an indented block after 'with' statement on line 2

# %%
def read_s3(value):
    with open("file.txt", 'a') as f:
     f.write(value)
    return f

read_s3("Adding this to file \n")
# Out:
# <_io.TextIOWrapper name='file.txt' mode='a' encoding='UTF-8'>

# %%
def read_s3(value):
    with open("file.txt", 'a') as f:
     f.write(value)
     return 

read_s3("Adding this to file \n")
# Out:
# <_io.TextIOWrapper name='file.txt' mode='a' encoding='UTF-8'>

# %%
def read_s3(value):
    with open("file.txt", 'a') as f:
     f.write(value)
     return 

read_s3("Adding this to file \n")

# %%
with open("file.txt", 'r') as f:
    print(f.read())
# Out:
# THIS IS A TEXT FILE 1
# THIS IS A TEXT FILE 2
# THIS IS A TEXT FILE 3 Adding this to file
# Adding this to file
# Adding this to file

# %%
def even_check(number):
    result = number % 2 == 0
    return result

even_check(20)
# Out:
# True

# %%
def list_check(list):
   for x in list:
       if x % 2 == 0:
         result = x
         print(result)
         return True
       else: pass


list_check(testing)
# Out:
# 2
# True

# %%
from random import shuffle
superlist = [1,2,3,4,5] 

def shuffle_list(mylist):
      shuffle(mylist)
      return mylist 

result = shuffle_list(superlist)
print(result)
# Out:
# [3, 4, 2, 1, 5]
